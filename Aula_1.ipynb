# %% [markdown]
# <a href="https://colab.research.google.com/github/ClaudiaCastiglione/InmersionDatos/blob/main/Aula_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Subo el archivo inmuebles_bogota.csv a mi explorador de archivos, o lo puedo leer de mi drive, al cual acabo de importar...
# importo la libreria pandas y luego le pido que lea dicho archivo con read_csv pasandole la ruta como parametro. Indexa los registros desde el 0 y arma un dataframe

# %%
import pandas as pd
inmuebles = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/inmuebles_bogota.csv')
inmuebles
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Baños  Área                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %% [markdown]
# lo guardé en la variable inmuebles

# %%
#inmuebles = pd.read_csv('/content/inmuebles_bogota.csv')

# %% [markdown]
# y con head() me muestra los primero cinco registros

# %%
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %% [markdown]
# Ahora, con sample(n), le pido una muestra aleatoria de n registros

# %%
inmuebles.sample(3)
# Out:
#              Tipo                          Descripcion  Habitaciones  Baños  \
# 4799  Apartamento  Apartamento en venta en Los Rosales             3      2
# 5948  Apartamento      Apartamento en venta en Usaquén             3      3
# 6496  Apartamento      Apartamento en venta en Tintala             3      2
#
#       Área       Barrio                                 UPZ            Valor
# 4799   133  Los Rosales  CHAPINERO: Chicó Lago + El Refugio    $ 870.000.000
# 5948   137      Usaquén                             Usaquén  $ 1.200.000.000
# 6496    89      Tintala                             Tintala    $ 372.000.000

# %% [markdown]
# Le pido que me diga cuantos registros hay y cuantas columnas

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %% [markdown]
# veo los titulos de las columnas

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# Armo una variable de tipo diccionario con titulo original :nuevo titulo de la columna listando solo aquellas que quiero renombrar, y en el rename asigno a colums dicha variable, eso le cambia el titulo a las columnas que meti en el diccionario.

# %%
columnas = {'Baños':'Banos', 'Área':'Area'}
inmuebles = inmuebles.rename(columns = columnas)
inmuebles.sample(3)
# Out:
#              Tipo                               Descripcion  Habitaciones  \
# 9505  Apartamento  Apartamento en venta en Colina Campestre             3
# 9427  Apartamento              Apartamento en venta en Niza             1
# 2916  Apartamento       Apartamento en venta en Los Rosales             3
#
#       Banos  Area            Barrio                                 UPZ  \
# 9505      2    80  Colina Campestre                                Niza
# 9427      1    50              Niza                                Niza
# 2916      3   125       Los Rosales  CHAPINERO: Chicó Lago + El Refugio
#
#               Valor
# 9505  $ 340.000.000
# 9427  $ 374.000.000
# 2916  $ 880.000.000

# %% [markdown]
# Con info() obtengo que tipo de dato se guarda en cada columna

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# con iloc[] puedo pedirle un registro especifico o un rango

# %%
inmuebles.iloc[9201]
# Out:
# Tipo                                       Apartamento
# Descripcion         Apartamento en venta en Las Nieves
# Habitaciones                                         1
# Banos                                                1
# Area                                                35
# Barrio                                      Las Nieves
# UPZ             SANTA FE: Las Nieves + Sagrado Corazón
# Valor                                    $ 310.000.000
# Name: 9201, dtype: object

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %% [markdown]
# Ojo, trae los registros 300 a 304, no incluye al extremo superior
#
# Para pedirle el dato de una columna de un registro especifico lo hago con[el nombre de la columna(entre'')][el numero del registro]

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %% [markdown]
# y podria hacer lo mismo para un rango de registros

# %%
inmuebles['Valor'][300:305]
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %% [markdown]
# Con type le pido qué tipo de estructura es ese listado de datos

# %%
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %% [markdown]
# calculo el promedio de las areas

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# Ahora recorro mi tabla evaluando una condicion y me muestra cada registro con un V o f segun corresponda.

# %%
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %% [markdown]
# Y ahora le pido cuantos hay que la cumplen, es como si le asignara un 1 a cada verdadero y un 0 a cada falso

# %%
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %% [markdown]
# Guardo esa "mascara " en una variable, y veo cual es su tipo

# %%
inmuebles_chico_reservado = (inmuebles.Barrio == 'Chico Reservado')
type(inmuebles_chico_reservado)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Le aplico la mascara a inmuebles y guardo eso en un nuevo dataframe. Es decir aplico el filtro para quedarme con los que estan en el barrio Chio Reservado y con ellos armo una nueva vista del set origianal de datos, que va atener esos 225 registros que cumplen la condicion.

# %%
chico_reservado = inmuebles[inmuebles_chico_reservado]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %% [markdown]
# calculo el promedio de todas aquellas columnas que son numericas para estos registros

# %%
chico_reservado.mean()
# Out:
# <ipython-input-21-921c71bdfe82>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   chico_reservado.mean()
# Habitaciones      2.506667
# Banos             2.844444
# Area            142.786667
# dtype: float64

# %% [markdown]
# o de solo del area, asi puedo compararla con el area promedio del set original

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %% [markdown]
# Quiero ver en mi dataset original cuantos barrios tengo

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %% [markdown]
# y para saber cuales son los nombres de los barrios y cuantos inmuebles hay en cada uno, y me los muestra ordenados segun dicha cantidad

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %% [markdown]
# ahora pido cuantas UPZ diferentes tengo y cuantas propiedades hay en cada una

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebles.UPZ.value_counts()
# Out:
# Usaquén                                  1681
# CHAPINERO: Pardo Rubio + Chapinero       1274
# USAQUÉN: Country Club + Santa Bárbara     771
# Bosa Central                              591
# Kennedy Central                           589
#                                          ...
# Localidad Usme resto                        2
# Las Cruces                                  2
# La Macarena                                 1
# Fontibón San Pablo                          1
# Zona Franca                                 1
# Name: UPZ, Length: 63, dtype: int64

# %% [markdown]
# Ahora voy a guardar en una variable los barrios con su cantidad de propiedades y voy a mostrarlo en un grafico de barras

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# como queda muy confuso dada la cantidad de barrios que hay, voy a graficar solo los datos de los 10 barrios que tienen mas propiedades (recordar que el values_counts ya los ordeno de mayor a menor cantidad) y uso un grafico de barras, que me ilustra la frecuencia con que aparece ese barrio

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# veo que los precios son strings, contienen el signo $

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %% [markdown]
# y si pretendo sumar a dos de esos datos en realidad los concatena

# %%
inmuebles.Valor[0] + inmuebles.Valor[1]
# Out:
# '$ 360.000.000$ 670.000.000'

# %% [markdown]
# De esta manera traigo los datos 'Valor' hasta el registro 5 (exclusive el cinco)

# %%
inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000
# 1      $ 670.000.000
# 2    $ 1.120.000.000
# 3      $ 890.000.000
# 4      $ 970.000.000
# Name: Valor, dtype: object

# %% [markdown]
# Ahora voy a separar el string en un array usando el espacio como separador por defecto, con el metodo split()

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %% [markdown]
# Hago esto con toda la columna 'Valor', para eso primero debo convertir todos sus datos en string. Toma cada elemento del panad.Series y me lo devuelve como lista

# %%
inmuebles.Valor.str.split()
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %%
type(inmuebles.Valor.str.split())
# Out:
# pandas.core.series.Series

# %% [markdown]
# Pasando dentro del split agrego en parametro expand = True lo convierto en un data frame, que tendra dos columnas

# %%
inmuebles.Valor.str.split(expand=True)
# Out:
#       0              1
# 0     $    360.000.000
# 1     $    670.000.000
# 2     $  1.120.000.000
# 3     $    890.000.000
# 4     $    970.000.000
# ...  ..            ...
# 9515  $    290.000.000
# 9516  $    670.000.000
# 9517  $    900.000.000
# 9518  $    335.000.000
# 9519  $    144.990.000
#
# [9520 rows x 2 columns]

# %% [markdown]
# Asi desdoblé la columna Valor en dos. Guardo este nuevo dataFrame en una variable y guardo cada una de sus columnas y las asigno a nuevas columnas del dataframe original

# %%
columna_valor_desdoblada = inmuebles.Valor.str.split(expand=True)
inmuebles['Moneda'] = columna_valor_desdoblada[0]
inmuebles['Precio'] = columna_valor_desdoblada[1]
inmuebles.sample(5)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 3603  Apartamento         Apartamento en venta en Bella Suiza             3
# 6379  Apartamento             Apartamento en venta en Usaquén             3
# 584   Apartamento            Apartamento en venta en Cedritos             2
# 6463  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 243   Apartamento       Apartamento en venta en Santa Barbara             3
#
#       Banos  Area              Barrio                                    UPZ  \
# 3603      2   101         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
# 6379      4   181             Usaquén                                Usaquén
# 584       2    70            Cedritos                                Usaquén
# 6463      2    56  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 243       3   114       Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
#
#               Valor Moneda       Precio
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %% [markdown]
# observo que el precio sigue siendo de tipo object (un string), antes de poder convertirlo en numerico primero debo eliminar el caracter especial . que separa a los miles usando el replace, con el caracter que quiero remplazar, cual es su reemplazo y el regex=True evita que me tire un warning, y pongo doble corchete cuando quiero que me muestre una lista de columnas y pandas entienda que lo que quiero es un dataframe

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','',regex=True)
inmuebles[['Barrio', 'Precio']]
# Out:
#                       Barrio      Precio
# 0         Zona Noroccidental   360000000
# 1                   Castilla   670000000
# 2            Chico Reservado  1120000000
# 3                    Usaquén   890000000
# 4                Bella Suiza   970000000
# ...                      ...         ...
# 9515                 Kennedy   290000000
# 9516  Parque Central Bavaria   670000000
# 9517                Restrepo   900000000
# 9518                Engativa   335000000
# 9519                 Tintala   144990000
#
# [9520 rows x 2 columns]

# %% [markdown]
# Ahora convierto el precio en un float, y ademas lo divido por 10000000

# %%
inmuebles['Precio_Millones'] = inmuebles.Precio.astype("float")/1000000

# %% [markdown]
# verifico que es un float

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Tipo             9520 non-null   object
#  1   Descripcion      9520 non-null   object
#  2   Habitaciones     9520 non-null   int64
#  3   Banos            9520 non-null   int64
#  4   Area             9520 non-null   int64
#  5   Barrio           9520 non-null   object
#  6   UPZ              9478 non-null   object
#  7   Valor            9520 non-null   object
#  8   Moneda           9520 non-null   object
#  9   Precio           9520 non-null   object
#  10  Precio_Millones  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %% [markdown]
# ahora uso la funcion describe() para hallar el count de registros no nulos, mean, max, min, la desviacion standar, los quartiles 25%, 50% (o mediana), 75% de todos aquellos sets de valores que sean numéricos

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millones
# count   9520.000000  9520.000000    9520.000000      9520.000000
# mean       3.072479     2.447899     146.664706       602.062354
# std        2.049856     1.255314    1731.379622       704.602062
# min        1.000000     0.000000       2.000000        60.000000
# 25%        2.000000     2.000000      57.000000       250.000000
# 50%        3.000000     2.000000      80.000000       409.182500
# 75%        3.000000     3.000000     135.000000       680.000000
# max      110.000000     9.000000  166243.000000     16000.000000

# %% [markdown]
# Ahora en las columnas quito ceros y usa una lambda para darle el formato

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' %x )
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millones
# count       9520.00 9520.00   9520.00          9520.00
# mean           3.07    2.45    146.66           602.06
# std            2.05    1.26   1731.38           704.60
# min            1.00    0.00      2.00            60.00
# 25%            2.00    2.00     57.00           250.00
# 50%            3.00    2.00     80.00           409.18
# 75%            3.00    3.00    135.00           680.00
# max          110.00    9.00 166243.00         16000.00

# %% [markdown]
# Ahora investigo algo raro, parece haber un inmueble con 110 habitaciones...lo localizo con loc y la condicion para hallarlo entre corchetes

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millones
# 897  Usaquén  $ 480.000.000      $  480000000           480.00

# %% [markdown]
# Habra que ver a que se debe ese dato incongruente, y tambien hay un inmueble con area 2...

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millones
# 8401           180.00

# %% [markdown]
# por eso es importante el analisis critico de los datos. Ahora podemos visualizar en un histograma, en el eje x, por ejemplo la nueva variable precio en millones, bins representa en cuantos tramos divide al intervalo de precios. El histograma muestra la distribucion de frecuencias.

# %%
inmuebles['Precio_Millones'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# disminuyo la cant de bins para que tengan mayor ancho

# %%
inmuebles['Precio_Millones'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# aumento la cantidad de bins para que tengan menor ancho

# %%
inmuebles['Precio_Millones'].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Y se observa que los precios de los inmuebles se ubican en su mayoria en el rango entre los 0 y 2000 millones. Ahora importo dos librerias que en conjunto permiten realizar graficos muy elaborados

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Con matplotlib genero un lienzo para realizar mi grafico, indicando el ancho y alto del mismo

# %%
plt.figure(figsize=(10,8))

# %% [markdown]
# y con seaborn dibujo el histograma, con el parametro bin_range podria seleccionar,el ancho de los rangos en histplot, entre muchos otros parametros. Le pongo un titulo a mi grafico. Lo muestro con plt.show()

# %%
grafica = sns.histplot(data=inmuebles, x='Precio_Millones')
grafica.set_title('Distribucion de los precios de los inmuebles')
plt.show()

# %% [markdown]
# achico el rango, mirando el describe vi que el valor minimo era de 60 millones, pongo que muestre la distribucion entre 50 y 2000, y detecta la mejor cantidad de bins pues bins=auto por defecto

# %%
grafica = sns.histplot(data=inmuebles, x='Precio_Millones')
grafica.set_title('Distribucion de los precios de los inmuebles')
plt.xlim((50, 2000))
plt.show()

# %% [markdown]
# y como el 75% de los precios estaban debajo de los 6800 millones, achico mas el rango, por ejemplo hasta 1000, y ademas agrego como parametro para que muestre la curva de densidad a kde=True en el histplot, es la curva que mas se ajusta a esa distribucion. Ademas lo quiero guardar con algun formato, entonces le pongo el camino y el formato dentro de la funcion savefig

# %%
grafica = sns.histplot(data=inmuebles, x='Precio_Millones', kde=True)
grafica.set_title('Distribucion de los precios de los inmuebles')
plt.xlim((50, 1000))
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Distribucion precios inmuebles.png' ,format='png')
plt.show()

# %% [markdown]
# le agrego una nueva dimension al grafico, por ejemplo para que muestre ademas el Tipo de inmueble, pasandolo en el parametro hue

# %%
grafica = sns.histplot(data=inmuebles, x='Precio_Millones', kde=True, hue='Tipo')
grafica.set_title('Distribucion de los precios de los inmuebles, junto a sus tipos')
plt.xlim((50, 1000))
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Distribucion precios inmuebles con sus tipos.png' ,format='png')
plt.show()

# %% [markdown]
# Ahora achico el rango en el eje y para que muestre oficinas y otros tipos de los cuales hay pocos inmuebles, es decir hago como un zoom al grafico

# %%
grafica = sns.histplot(data=inmuebles, x='Precio_Millones', kde=True, hue='Tipo')
grafica.set_title('Distribucion de los precios de los inmuebles, junto a los tipos cuya frecuencia es menor')
plt.xlim((50, 1000))
plt.ylim((0, 20))
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Distribucion precios inmuebles con sus tipos con menor frecuencia mas visibles.png' ,format='png')
plt.show()

# %% [markdown]
# Promedio de área de todos los inmuebles en los barrios en el dataset. El top 10.

# %%
#Solución 1
promedio_area = inmuebles.groupby('Barrio')['Area'].mean()
promedio_area.sort_values(ascending=False).head(10).plot.bar(color="green")
# Out:
# <Axes: xlabel='Barrio'>

# %%
#Solución 2
promedio_area = inmuebles.groupby('Barrio')['Area'].median()
promedio_area.sort_values(ascending=False).head(10).plot.bar(color="green")
# Out:
# <Axes: xlabel='Barrio'>

# %%
#Promedio de área del top 10 de barrios
top_10 = inmuebles.Barrio.value_counts().head(10).index
top_10 = inmuebles[inmuebles.Barrio.isin(top_10)]
promedio_area = top_10.groupby('Barrio')['Area'].median()
promedio_area.sort_values(ascending=False).plot.bar(color="green")
# Out:
# <Axes: xlabel='Barrio'>

# %%
inmuebles.groupby('Barrio')['Area'].describe()
# Out:
#                     count   mean    std   min    25%    50%    75%     max
# Barrio
# Alameda              1.00  97.00    NaN 97.00  97.00  97.00  97.00   97.00
# Alhambra            17.00 190.41  99.78 50.00 112.00 164.00 300.00  360.00
# Andes Norte          7.00 124.86  49.78 42.00 105.00 108.00 167.00  180.00
# Antonio Nariño      48.00 163.06 151.02 32.00  58.75  72.00 281.25  554.00
# Barrancas           15.00  70.20   7.02 63.00  63.00  75.00  76.50   78.00
# ...                   ...    ...    ...   ...    ...    ...    ...     ...
# Villa Maria         13.00 207.15  47.31 51.00 222.00 222.00 222.00  222.00
# Villas De Granada   22.00  86.59  51.35 50.00  64.00  64.00  80.50  260.00
# Villemar            18.00  76.89  48.50 45.00  54.25  59.00  59.00  224.00
# Zona Franca          1.00  54.00    NaN 54.00  54.00  54.00  54.00   54.00
# Zona Noroccidental 877.00 135.79 223.81 16.00  61.00  78.00 120.00 5458.00
#
# [149 rows x 8 columns]

# %%
inmuebles.groupby('Barrio')['Habitaciones'].describe()
# Out:
#                     count  mean  std  min  25%  50%  75%   max
# Barrio
# Alameda              1.00  3.00  NaN 3.00 3.00 3.00 3.00  3.00
# Alhambra            17.00  3.00 0.87 1.00 3.00 3.00 4.00  4.00
# Andes Norte          7.00  3.00 1.00 1.00 3.00 3.00 3.50  4.00
# Antonio Nariño      48.00  4.31 3.10 1.00 3.00 3.00 5.00 14.00
# Barrancas           15.00  2.87 0.35 2.00 3.00 3.00 3.00  3.00
# ...                   ...   ...  ...  ...  ...  ...  ...   ...
# Villa Maria         13.00  4.69 0.75 3.00 5.00 5.00 5.00  5.00
# Villas De Granada   22.00  3.45 0.86 3.00 3.00 3.00 3.75  6.00
# Villemar            18.00  2.94 1.16 2.00 2.00 3.00 3.00  7.00
# Zona Franca          1.00  2.00  NaN 2.00 2.00 2.00 2.00  2.00
# Zona Noroccidental 877.00  3.17 1.73 1.00 3.00 3.00 3.00 32.00
#
# [149 rows x 8 columns]

# %%
inmuebles.groupby('Barrio')['Banos'].describe()
# Out:
#                     count  mean  std  min  25%  50%  75%  max
# Barrio
# Alameda              1.00  2.00  NaN 2.00 2.00 2.00 2.00 2.00
# Alhambra            17.00  2.94 1.25 1.00 2.00 2.00 4.00 5.00
# Andes Norte          7.00  2.86 0.38 2.00 3.00 3.00 3.00 3.00
# Antonio Nariño      48.00  2.50 1.56 1.00 1.00 2.00 3.00 6.00
# Barrancas           15.00  2.13 0.35 2.00 2.00 2.00 2.00 3.00
# ...                   ...   ...  ...  ...  ...  ...  ...  ...
# Villa Maria         13.00  3.69 0.75 2.00 4.00 4.00 4.00 4.00
# Villas De Granada   22.00  2.32 0.65 2.00 2.00 2.00 2.00 4.00
# Villemar            18.00  2.06 0.80 1.00 2.00 2.00 2.00 5.00
# Zona Franca          1.00  1.00  NaN 1.00 1.00 1.00 1.00 1.00
# Zona Noroccidental 877.00  2.51 1.28 1.00 2.00 2.00 3.00 9.00
#
# [149 rows x 8 columns]

# %% [markdown]
# Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles (Refinar el gráfico: Títulos, aumentar el tamaño de labels, colores, conclusión de la información)

# %%
# Establecer un tema
sns.set_style("white")
sns.set_palette("bright")
sns.color_palette("cubehelix", as_cmap=True)

#font = {'family' : 'League Gothic Regular', 'weight' : 'normal', 'size'   : 12}
#plt.rc('font', **font)

#plt.ylim((0,300))
plt.xlim((500,10000)) #Se configura el limite minimo y maximo
# Gráfico
grafica5 = sns.histplot(data=inmuebles.query("Tipo in ['Lote','Edificio','Finca']"), 
                        x='Precio_Millones',hue='Tipo',fill=True,kde=False)#,multiple="dodge",element="step")
# Personaliza el histograma
grafica5.set_title('Distribución de valores de los inmuebles en Bogotá', fontsize=20)#, font=font)
grafica5.set_xlabel('Precio en millones', fontsize=15)
grafica5.set_ylabel('Total de inmuebles', fontsize=15)
plt.show()
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Distribucion con tres tipos de inmuebles.png',format='png')

# %% [markdown]
# **Conclusiones**
# Según la gráfica sólo un numero limitado de Lotes estan disponibles en
# un rango de precio desde los 500 a los 2000 millones de pesos colombianos.
# Fincas hay disponibles solo en el precio de 2000, 4000 y 6000 millones
# Edificio es lo que mas hay disponible de estos 3 tipos de edificios, habiendo varias mas existencias en rango de precio de 0 a 2000 millones, en el rango de 8000 y 10,000 millones.

# %%
plt.figure(figsize=(12,8))

g = sns.histplot(x="Precio_Millones",
                 kde=True,
                 hue="Tipo",
                 hue_order=["Apartamento", "Casa", "Finca"],
                 palette="Paired",
                 data=inmuebles)

g.set_title("Distribución de precios de inmuebles en Bogotá, Colombia", fontsize=14)

plt.setp(g.get_legend().get_title(), fontsize=12)
plt.setp(g.get_legend().get_texts(), fontsize=12)

plt.xlim((50, 1000))
g.set_xlabel("Precio (Peso Colombiano en millones)", fontsize=13)
g.set_ylabel("Cantidad", fontsize=13)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Distribucion con tres tipos de inmuebles.png',format='png')

plt.show()

# %% [markdown]
# **Conclusión:**
# El análisis del gráfico revela una gran diferencia en la oferta de apartamentos y casas en los estratos de precios más bajos, siendo la oferta de apartamentos hasta 7 veces mayor que la de las casas.
#
# A medida que los precios aumentan, se observa una disminución en la brecha de la oferta de casas y apartamentos y, en los estratos de precios más altos, la cantidad de casas y apartamentos es muy similar. Esto sugiere que el mercado de venta de inmuebles de alta gama en Bogotá es equilibrado en términos de la oferta de casas y apartamentos.
#
# En el caso de las fincas, su oferta es significativamente baja en todos los estratos de precios. Por lo tanto, se puede concluir que el mercado de venta de fincas en Bogotá es relativamente limitado en comparación con el de casas y apartamentos.

# %% [markdown]
# Precio del m² por barrio y el grafico mejor para esta variable

# %%
inmuebles['Valor_m2_Millon'] = inmuebles['Precio_Millones']/inmuebles['Area']
inmuebles.sample(3)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 6765  Apartamento           Apartamento en venta en Bosa             2      1
# 7614  Apartamento      Apartamento en venta en Normandia             1      2
# 4538  Apartamento  Apartamento en venta en Santa Barbara             4      5
#
#       Area         Barrio                                         UPZ  \
# 6765    47           Bosa                                Bosa Central
# 7614    56      Normandia  ENGATIVÁ: Santa Cecilia + Jardín  Botánico
# 4538   382  Santa Barbara       USAQUÉN: Country Club + Santa Bárbara
#
#                 Valor Moneda      Precio  Precio_Millones  Valor_m²_Millon  \
# 6765    $ 119.000.000      $   119000000           119.00             2.53
# 7614    $ 465.000.000      $   465000000           465.00             8.30
# 4538  $ 1.900.000.000      $  1900000000          1900.00             4.97
#
#       Valor_m²_Barrio  Valor_m2_Millon
# ...

# %% [markdown]
# Ahora agrupo por barrio los datos numéricos, para eso necesito usar alguna funcion de agregacion, en este caso el mean o promedio. Aca obtengo un valor promedio para el m² para cada barrio, pero no es la forma mejor de calcularlo

# %%
inmuebles.groupby('Barrio').mean()
# Out:
#                     Habitaciones  Banos   Area  Precio_Millones  \
# Barrio
# Alameda                     3.00   2.00  97.00           580.00
# Alhambra                    3.00   2.94 190.41           752.35
# Andes Norte                 3.00   2.86 124.86           709.57
# Antonio Nariño              4.31   2.50 163.06           459.22
# Barrancas                   2.87   2.13  70.20           314.13
# ...                          ...    ...    ...              ...
# Villa Maria                 4.69   3.69 207.15           402.85
# Villas De Granada           3.45   2.32  86.59           282.30
# Villemar                    2.94   2.06  76.89           303.83
# Zona Franca                 2.00   1.00  54.00           160.00
# Zona Noroccidental          3.17   2.51 135.79           620.81
#
#                     Valor_m²_Millon
# Barrio
# Alameda                        5.98
# Alhambra                       4.33
# Andes Norte                    6.05
# ...

# %% [markdown]
# ahora veo por ejemplo cuantas habitaciones en total hay en cada barrio, cuantos baños en total, cuantos metros en total

# %%
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millones  \
# Barrio
# Alameda                        3      2      97           580.00
# Alhambra                      51     50    3237         12790.00
# Andes Norte                   21     20     874          4967.00
# Antonio Nariño               207    120    7827         22042.65
# Barrancas                     43     32    1053          4712.00
# ...                          ...    ...     ...              ...
# Villa Maria                   61     48    2693          5237.00
# Villas De Granada             76     51    1905          6210.62
# Villemar                      53     37    1384          5469.00
# Zona Franca                    2      1      54           160.00
# Zona Noroccidental          2778   2204  119084        544453.06
#
#                     Valor_m²_Millon  Valor_m²_Barrio  Valor_m2_Millon
# Barrio
# Alameda                        5.98             5.98             5.98
# ...

# %% [markdown]
# La mejor forma de calcular el precio del m² para cada barrio es éste:

# %%
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_Millones'] / datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millones  \
# Barrio
# Alameda                        3      2      97           580.00
# Alhambra                      51     50    3237         12790.00
# Andes Norte                   21     20     874          4967.00
# Antonio Nariño               207    120    7827         22042.65
# Barrancas                     43     32    1053          4712.00
# ...                          ...    ...     ...              ...
# Villa Maria                   61     48    2693          5237.00
# Villas De Granada             76     51    1905          6210.62
# Villemar                      53     37    1384          5469.00
# Zona Franca                    2      1      54           160.00
# Zona Noroccidental          2778   2204  119084        544453.06
#
#                     Valor_m²_Millon  Valor_m²_Barrio  Valor_m2_Millon  \
# Barrio
# Alameda                        5.98             5.98             5.98
# ...

# %% [markdown]
# Ahora voy a remplazar estos valores de precio por m² en mi dataframe original, primero un diccionario.

# %%
valor_m2_barrio = dict(datos_barrio['Valor_m2_Barrio'])
valor_m2_barrio
# Out:
# {'Alameda': 5.979381443298969,
#  'Alhambra': 3.95118937287612,
#  'Andes Norte': 5.683066361556064,
#  'Antonio Nariño': 2.816232272901495,
#  'Barrancas': 4.4748338081671415,
#  'Barrios Unidos': 2.9599171141243064,
#  'Bella Suiza': 6.2905507012394,
#  'Bellavista Occidental': 2.522711390635919,
#  'Bochica': 3.4078212290502794,
#  'Bogotá D.C': 5.212760277629472,
#  'Bosa': 2.6778451358697213,
#  'Bosa Piamonte': 1.175,
#  'Bosa Porvenir': 3.1666666666666665,
#  'Bosque De Pinos': 6.046475195822455,
#  'Bosque Popular': 3.864097363083164,
#  'Boyaca ': 2.637421499815294,
#  'Buenos Aires': 2.6,
#  'Candelaria La Nueva': 4.0625,
#  'Cantagallo': 5.71920581655481,
#  'Capellania': 4.316791690709752,
#  'Casablanca': 6.245421245421245,
#  'Castilla': 3.4035893155258763,
#  'Cedritos': 5.027419586695463,
#  'Cerros De Suba': 6.202830188679245,
#  'Chapinero': 4.58018576602501,
#  'Chapinero Alto': 6.4239336492891,
#  'Chapinero Central': 6.360286919831224,
# ...

# %% [markdown]
# Creo en el dataframe una nueva columna con el titulo que le quiero dar y en ella alojo la columna Barrio, y luego la mapeo segun el diccionario, convirtiendo cada barrio en su precio por m²

# %%
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(valor_m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millones  Valor_m²_Millon  \
# ...

# %% [markdown]
# Cuento para cada barrio cuantos inmuebles hay

# %%
inmuebles['Barrio'].value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %% [markdown]
# aqui el barrio funciona como indice, tomo los 10 barrios que tienen mas inmuebles, uso la slice notation y pido el atributo index

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index
top_barrios
# Out:
# Index(['Usaquén', 'Zona Noroccidental', 'Bosa', 'Kennedy', 'Cedritos',
#        'Barrios Unidos', 'Engativa', 'Suba', 'Santa Barbara', 'Chapinero'],
#       dtype='object')

# %% [markdown]
# En datos barrio el index era barrio, ahora transformo barrio en una columna, reseteando como index la secuencia de enteros

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millones  \
# 0               Alameda             3      2      97           580.00
# 1              Alhambra            51     50    3237         12790.00
# 2           Andes Norte            21     20     874          4967.00
# 3        Antonio Nariño           207    120    7827         22042.65
# 4             Barrancas            43     32    1053          4712.00
# ..                  ...           ...    ...     ...              ...
# 144         Villa Maria            61     48    2693          5237.00
# 145   Villas De Granada            76     51    1905          6210.62
# 146            Villemar            53     37    1384          5469.00
# 147         Zona Franca             2      1      54           160.00
# 148  Zona Noroccidental          2778   2204  119084        544453.06
#
#      Valor_m²_Millon  Valor_m²_Barrio
# 0               5.98             5.98
# 1              73.56             3.95
# ...

# %% [markdown]
# hago una query, que me trae todos los datos de aquellos barrios que esta en el  top 10, la @es para referir a la variable definida mas arriba

# %%
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millones  \
# 5        Barrios Unidos          1525   1196   87799        259877.76
# 10                 Bosa          1743    789   34879         93400.56
# 22             Cedritos          1458   1348   53711        270027.73
# 24            Chapinero           892    913   81248        372130.93
# 50             Engativa          1676   1077   59808        172711.73
# 63              Kennedy          2151   1233   61475        207963.65
# 125       Santa Barbara          1073   1162   54693        320097.80
# 132                Suba          1497   1202   61615        266406.04
# 138             Usaquén          3109   3044  148121        837710.36
# 148  Zona Noroccidental          2778   2204  119084        544453.06
#
#      Valor_m²_Millon  Valor_m²_Barrio
# 5            2070.61             2.96
# 10           1654.36             2.68
# 22           2853.23             5.03
# 24           2466.03             4.58
# ...

# %% [markdown]
# hago un grafico de barras para verlos, usando la query como fuente de datos y para que no se superpongan los nombres mas largos, roto los tick 45°.OJO este top ten me muestra, cual es el valor del m² en los 10 barrios que tienen mas inmuebles, NO los 10 cuyos precios por m² son los mas altos.

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x='Barrio',y='Valor_m2_Barrio', data=datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
ax.set_title('Barrios top ten')
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Barrios top ten.png',format='png')
plt.show()

# %% [markdown]
# Empiezo a usar ahora grafico de cajas, boxplot

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Valor_m2_Barrio', data=datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
ax.set_title('Barrios top ten')
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Boxplot Barrios top ten.png',format='png')
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Precio_Millones', data=datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
ax.set_title('Barrios top ten, precio en millones')
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Boxplot Barrios top ten precios en millones.png',format='png')
plt.show()

# %% [markdown]
# Ahora hago el boxplot para graficar el valor del m² en millones con todo inmuebles como set de datos para la query

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Valor_m2_Millon', data=inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
ax.set_title('Precio del m2 de barrios top ten')
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Grafico de cajas valor del m2 en barrios del top ten con todo inmuebles como set de datos.png',format='png')
plt.show()

# %% [markdown]
# Como se interpreta? Muestra los valores maximos y minimos (las lineas horizontales) que no son absolutos, sino sin contar los datos outlawers, el borde inferior de la cajita representa el primer cuartil, la linea del medio el segundo cuartil o mediana, el borde superior el tercer quartil(es decir que el 75% de los datos quedan por debajo de ese valor) y los rombitos son aquellos valores que se apartan del comportamiento normal, los outlawers.

# %% [markdown]
# ahora voy a dejar fuera los outlawers para que sea mas legible, observo que en el grafico si limito el valor del m² por millon a menos de 12 quedarian afuera los rombitos, eso lo agrego como condicion en la query

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Valor_m2_Millon', data=inmuebles.query('Barrio in @top_barrios & Valor_m2_Millon < 15'))
ax.tick_params(axis='x', rotation=45)
ax.set_title('Precio del m2 de barrios top ten')
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Grafico de cajas valor del m2 en barrios del top ten con todo inmuebles como set de datos, sin outlawers.png',format='png')
plt.show()

# %% [markdown]
# repito para el area

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Area', data=inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
ax.set_title('Area de barrios top ten')
plt.show()

# %% [markdown]
# veo que tiene sentido limitar el area a menos de 500m² por ejemplo

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Area', data=inmuebles.query('Barrio in @top_barrios & Area < 500'))
ax.tick_params(axis='x', rotation=45)
ax.set_title('Area de barrios top ten')
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Grafico de cajas del area en barrios del top ten.png',format='png')
plt.show()

# %% [markdown]
# Cuando los datos estan muy dispersos hay que considerar muy cuidadosamente los outlawers, para ver cuales de los datos pueden modificar el desempeño del modelo. Como el valor de la mediana es mayor en la ultima caja, es en ese barrio donde buscaria si quisiera una casa grande

# %% [markdown]
# Repito para el precio en millones

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Precio_Millones', data=inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
ax.set_title('Area de barrios top ten')
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Grafico de cajas del precio en millones en barrios del top ten.png',format='png')
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Precio_Millones', data=inmuebles.query('Barrio in @top_barrios & Precio_Millones < 2000'))
ax.tick_params(axis='x', rotation=45)
ax.set_title('Area de barrios top ten')
plt.savefig('/content/drive/MyDrive/Colab Notebooks/Grafico2 de cajas del precio en barrios del top ten.png',format='png')
plt.show()

# %% [markdown]
# Ahora voy a hacer un **GRAFICO INTERACTIVO**

# %%
columnas_categoricas = ['Tipo','Barrio','UPZ']
from ipywidgets import interact
import ipywidgets as widgets

menu = widgets.Dropdown(options=columnas_categoricas,
                        value=columnas_categoricas[0],
                        description='Selecciona una columna')

def histograma(columna):
  g = sns.histplot(x=columna,                 
                 data=top_10)
  if len(inmuebles[columna].unique()) > 4:
    g.tick_params(axis='x',rotation=90)
  plt.show()

interact(histograma,columna=menu)
# Out:
# interactive(children=(Dropdown(description='Selecciona una columna', options=('Tipo', 'Barrio', 'UPZ'), value=…
# <function __main__.histograma(columna)>

# %% [markdown]
# Como no tengo muchos atributos (solo la cant de habitaciones, baños, m², ubicacion, etc) no puedo realmente hacer un estudio de las variables que influyen en el valor de un inmueble. Por eso, a continuacion) voy a utilizar una encuesta relizada a los habitantes, por el DANE (el indec de Colombia) para obtener info socioeconomica y de entorno urbano que permitiera formular, hacer seguimiento y evaluar politicas distritales. Esto me va a permitir trabajar con mas variables. Este es el sitio https://microdatos.dane.gov.co/index.php/catalog/743 y en el diccionario de datos puedo ver todas las tablas que contiene, de las cuales solo voy a usar algunas.

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/Identificacion (Capitulo A).csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-111-db1067be397f> in <cell line: 1>()
# ----> 1 datos_raw = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/Identificacion (Capitulo A).csv')
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# como no lo puede leer , le digo el encoding, de algun lado saca que es latin-1 ????

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/Identificacion (Capitulo A).csv', encoding='latin-1')
datos_raw
# Out:
#                                                     DIRECTORIO;"DPTO";"MPIO";"CLASE";"COD_LOCALIDAD";"NOMBRE_LOCALIDAD";"COD_UPZ_GRUPO";"NOMBRE_UPZ_GRUPO";"ESTRATO2021";"NOMBRE_ESTRATO";"FEX_C"
# 3004346;11;11001;1;3;"Santa Fe";814;"SANTA FE: ...                                      2266692027239
# 3004347;11;11001;1;14;"Los Mártires";37;"Santa ...                                      8555889419101
# 3004348;11;11001;1;3;"Santa Fe";814;"SANTA FE: ...                                       286103658331
# 3004349;11;11001;1;1;"Usaquén";803;"USAQUÉN: Co...                                      6502122142802
# 3004350;11;11001;1;1;"Usaquén";803;"USAQUÉN: Co...                                      4684068319009
# ...                                                                                               ...
# 3004341;11;11001;1;3;"Santa Fe";814;"SANTA FE: ...                                     40228287385068
# ...

# %% [markdown]
# No acomoda bien los titulos y los datos en las columnas, pues como se observa los separadores son en este caso ; y no , necesito pasarlo también como parametro

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/Identificacion (Capitulo A).csv', sep= ';', encoding='latin-1')
datos_raw
# Out:
#         DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0       3004346.00    11  11001      1           3.00         Santa Fe
# 1       3004347.00    11  11001      1          14.00     Los Mártires
# 2       3004348.00    11  11001      1           3.00         Santa Fe
# 3       3004349.00    11  11001      1           1.00          Usaquén
# 4       3004350.00    11  11001      1           1.00          Usaquén
# ...            ...   ...    ...    ...            ...              ...
# 106462  3004341.00    11  11001      1           3.00         Santa Fe
# 106463  3004342.00    11  11001      1           3.00         Santa Fe
# 106464  3004343.00    11  11001      1          14.00     Los Mártires
# 106465  3004344.00    11  11001      1           3.00         Santa Fe
# 106466  3004345.00    11  11001      1           3.00         Santa Fe
#
#         COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# ...

# %% [markdown]
# Como se hizo no solo en Bogota, sino también en otros municipios que no me interesan (en el link eso aparece en la documentacion, voy a buscar como codifica los mismos el DANE, y de alli obtengo que el correspondiente a esa Ciudad es el 11001

# %%
datos_raw.shape
# Out:
# (106467, 11)

# %% [markdown]
# es decir tengo 106467 registros pero los que no son Bogota no me interesan

# %%
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.sample(3)
# Out:
#         DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 71345   1126133.00    11  11001      1          11.00             Suba
# 33564   1010483.00    11  11001      3           5.00             Usme
# 105772  3003625.00    11  11001      1          10.00         Engativá
#
#         COD_UPZ_GRUPO NOMBRE_UPZ_GRUPO  ESTRATO2021        NOMBRE_ESTRATO  \
# 71345           28.00        El Rincón     11001122             El Rincón
# 33564             NaN              NaN     11001205  Localidad Usme resto
# 105772         116.00           Álamos     11001197                Álamos
#
#                    FEX_C
# 71345   81,9946966970744
# 33564   4,88816414268526
# 105772   2,7841117582056

# %% [markdown]
# y veo que elimine cerca de 20000 filas que no me interesan

# %%
datos_raw.shape
# Out:
# (86504, 11)

# %% [markdown]
# Ahora seguiria importando las tablas que me interesa (para eso primero deberia hacer un estudio del diccionario!!!), lo puedo hacer una a una o de la siguiente forma

# %%
tablas=['Identificacion (Capitulo A).csv',
        'Datos de la vivenda y su entorno (Capitulo B).csv',
        'Condiciones habitacionales del hogar (Capitulo C).csv',
        'Composicion del hogar y demografia (Capitulo E).csv',
        'Educacion (Capitulo H).csv',
        'Fuerza de trabajo (Capitulo K).csv',
        'Percepcion sobre las condiciones de vida y el desempeno institucional (Capitulo L).csv']

archivos=[]

for t in tablas:
  datos = pd.read_csv(f'/content/drive/MyDrive/Colab Notebooks/archivos-dane/{t}', 
                  sep = ';',encoding='latin-1',low_memory=False)
  archivos.append(datos)

datos_a,datos_b,datos_c,datos_e,datos_h,datos_k,datos_l = archivos[:7]

# %% [markdown]
# hago un merge entre datos_a y datos_b a través del campo que las relaciona que es DIRECTORIO y hago un leftjoin a izquierda porque quiero mantener todos los registros de la encuesta

# %%
datos_dane =pd.merge(datos_raw, datos_b, on ='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (86504, 73)

# %% [markdown]
# veo que las columnas pasaron de 11 a 73, y lo repito con todas las tablas

# %%
datos_dane =pd.merge(datos_dane, datos_c, on ='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane =pd.merge(datos_dane, datos_e, on ='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# <ipython-input-129-6c44247fabad>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane =pd.merge(datos_dane, datos_e, on ='DIRECTORIO', how='left')
# (238559, 281)

# %% [markdown]
# Aparecieron mas filas porque la tabla e probablemente tenis mas preguntas y eso agrego con el mismo DIRECTORIO nuevas filas ???
# Observar arriba a la derecha que aumento la memoria RAM utilizada.
# Y no todas las columnas me van a servir, ademas.

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %% [markdown]
# Como esa info estaba en crudo, la remplazo por una depurada por el docente

# %%
datos_dane = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/datos_dane.csv')
datos_dane.head(5)
# Out:
#    DIRECTORIO NOMBRE_LOCALIDAD                                 NOMBRE_ESTRATO  \
# 0  3004368.00          Usaquén  USAQUÉN: Paseo de Los Libertadores + La Uribe
# 1  3004369.00          Usaquén                                        Usaquén
# 2  3004375.00        Chapinero             CHAPINERO: Pardo Rubio + Chapinero
# 3  3004380.00          Usaquén                                     Los Cedros
# 4  3004383.00         Fontibón                      Ciudad Salitre Occidental
#
#    NVCBP4  NVCBP14A  NVCBP14D  NVCBP14E  NVCBP14G  NVCBP15A  NVCBP15C  ...  \
# 0       1         2         2         2         2         2         2  ...
# 1       1         2         2         2         2         2         2  ...
# 2       2         2         2         2         2         2         1  ...
# 3       1         2         2         2         2         2         2  ...
# 4       1         2         2         2         2         1         2  ...
#
# ...

# %%
datos_dane.shape
# Out:
# (9857, 55)

# %%
datos_dane.info
# Out:
# <bound method DataFrame.info of       DIRECTORIO NOMBRE_LOCALIDAD  \
# 0     3004368.00          Usaquén
# 1     3004369.00          Usaquén
# 2     3004375.00        Chapinero
# 3     3004380.00          Usaquén
# 4     3004383.00         Fontibón
# ...          ...              ...
# 9852  3004289.00         Santa Fe
# 9853  3004294.00         Santa Fe
# 9854  3004303.00         Santa Fe
# 9855  3004328.00         Santa Fe
# 9856  3004338.00     Los Mártires
#
#                                      NOMBRE_ESTRATO  NVCBP4  NVCBP14A  \
# 0     USAQUÉN: Paseo de Los Libertadores + La Uribe       1         2
# 1                                           Usaquén       1         2
# 2                CHAPINERO: Pardo Rubio + Chapinero       2         2
# 3                                        Los Cedros       1         2
# 4                         Ciudad Salitre Occidental       1         2
# ...                                             ...     ...       ...
# ...

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DIRECTORIO        9857 non-null   float64
#  1   NOMBRE_LOCALIDAD  9857 non-null   object
#  2   NOMBRE_ESTRATO    9857 non-null   object
#  3   NVCBP4            9857 non-null   int64
#  4   NVCBP14A          9857 non-null   int64
#  5   NVCBP14D          9857 non-null   int64
#  6   NVCBP14E          9857 non-null   int64
#  7   NVCBP14G          9857 non-null   int64
#  8   NVCBP15A          9857 non-null   int64
#  9   NVCBP15C          9857 non-null   int64
#  10  NVCBP15F          9857 non-null   int64
#  11  NVCBP15G          9857 non-null   int64
#  12  NVCBP16A3         9857 non-null   int64
#  13  NVCBP16A4         9857 non-null   int64
#  14  NPCKP17           9857 non-null   float64
#  15  NPCKP18           9857 non-null   float64
# ...

# %% [markdown]
# Yendo a la documentacion puedo ver qué significan toods esos codigos que figuran como titulo en las columnas, creando un diccionario les cambio el nombre

# %%
dic_dane = {
       'NVCBP4':'CONJUNTO_CERRADO',
       'NVCBP14A':'FABRICAS_CERCA', 'NVCBP14D':'TERMINALES_BUS', 'NVCBP14E':'BARES_DISCO', 
       'NVCBP14G':'OSCURO_PELIGROSO', 'NVCBP15A':'RUIDO', 'NVCBP15C':'INSEGURIDAD',
       'NVCBP15F':'BASURA_INADECUADA', 'NVCBP15G':'INVASION','NVCBP16A3':'MOV_ADULTOS_MAYORES', 
       'NVCBP16A4':'MOV_NINOS_BEBES',
       'NPCKP17':'OCUPACION','NPCKP18':'CONTRATO','NPCKP23':'SALARIO_MES', 
       'NPCKP44A':'DONDE_TRABAJA', 'NPCKPN62A':'DECLARACION_RENTA', 
       'NPCKPN62B':'VALOR_DECLARACION', 'NPCKP64A':'PERDIDA_TRABAJO_C19', 
       'NPCKP64E':'PERDIDA_INGRESOS_C19',
       'NHCCP3':'TIENE_ESCRITURA', 'NHCCP6':'ANO_COMPRA', 'NHCCP7':'VALOR_COMPRA', 'NHCCP8_1':'HIPOTECA_CRED_BANCO',
       'NHCCP8_2':'OTRO_CRED_BANCO', 'NHCCP8_3':'CRED_FNA', 'NHCCP8_6':'PRESTAMOS_AMIGOS',
       'NHCCP8_7':'CESANTIAS', 'NHCCP8_8':'AHORROS', 'NHCCP8_9':'SUBSIDIOS',
       'NHCCP9':'CUANTO_PAGARIA_MENSUAL', 'NHCCP11':'PLANES_ADQUIRIR_VIVIENDA', 
       'NHCCP11A':'MOTIVO_COMPRA', 'NHCCP12':'RAZON_NO_ADQ_VIV', 'NHCCP41':'TIENE_CARRO','NHCCP41A':'CUANTOS_CARROS',
       'NHCCP47A':'TIENE_PERROS', 'NHCCP47B':'TIENE_GATOS', 'NHCLP2A':'VICTIMA_ATRACO', 'NHCLP2B':'VICTIMA_HOMICIDIO', 
       'NHCLP2C':'VICTIMA_PERSECUSION',
       'NHCLP2E':'VICTIMA_ACOSO', 'NHCLP4':'COMO_VIVE_ECON', 'NHCLP5':'COMO_NIVEL_VIDA', 
       'NHCLP8AB':'REACCION_OPORTUNA_POLICIA', 'NHCLP8AE':'COMO_TRANSPORTE_URBANO', 'NHCLP10':'SON_INGRESOS_SUFICIENTES',
       'NHCLP11':'SE_CONSIDERA_POBRE', 'NHCLP29_1A':'MED_C19_TRABAJO', 
       'NHCLP29_1C':'MED_C19_CAMBIO_VIVIENDA', 'NHCLP29_1E':'MED_C19_ENDEUDAMIENTO', 
       'NHCLP29_1F':'MED_C19_VENTA_BIENES','NPCHP4':'NIVEL_EDUCATIVO'
       }

datos_dane = datos_dane.rename(columns=dic_dane)
datos_dane.columns
# Out:
# Index(['DIRECTORIO', 'NOMBRE_LOCALIDAD', 'NOMBRE_ESTRATO', 'CONJUNTO_CERRADO',
#        'FABRICAS_CERCA', 'TERMINALES_BUS', 'BARES_DISCO', 'OSCURO_PELIGROSO',
#        'RUIDO', 'INSEGURIDAD', 'BASURA_INADECUADA', 'INVASION',
#        'MOV_ADULTOS_MAYORES', 'MOV_NINOS_BEBES', 'OCUPACION', 'CONTRATO',
#        'SALARIO_MES', 'DONDE_TRABAJA', 'DECLARACION_RENTA',
#        'VALOR_DECLARACION', 'PERDIDA_TRABAJO_C19', 'PERDIDA_INGRESOS_C19',
#        'TIENE_ESCRITURA', 'ANO_COMPRA', 'VALOR_COMPRA', 'HIPOTECA_CRED_BANCO',
#        'OTRO_CRED_BANCO', 'CRED_FNA', 'PRESTAMOS_AMIGOS', 'CESANTIAS',
#        'AHORROS', 'SUBSIDIOS', 'CUANTO_PAGARIA_MENSUAL',
#        'PLANES_ADQUIRIR_VIVIENDA', 'MOTIVO_COMPRA', 'RAZON_NO_ADQ_VIV',
#        'TIENE_CARRO', 'CUANTOS_CARROS', 'TIENE_PERROS', 'TIENE_GATOS',
#        'VICTIMA_ATRACO', 'VICTIMA_HOMICIDIO', 'VICTIMA_PERSECUSION',
#        'VICTIMA_ACOSO', 'COMO_VIVE_ECON', 'COMO_NIVEL_VIDA',
#        'REACCION_OPORTUNA_POLICIA', 'COMO_TRANSPORTE_URBANO',
# ...

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DIRECTORIO                 9857 non-null   float64
#  1   NOMBRE_LOCALIDAD           9857 non-null   object
#  2   NOMBRE_ESTRATO             9857 non-null   object
#  3   CONJUNTO_CERRADO           9857 non-null   int64
#  4   FABRICAS_CERCA             9857 non-null   int64
#  5   TERMINALES_BUS             9857 non-null   int64
#  6   BARES_DISCO                9857 non-null   int64
#  7   OSCURO_PELIGROSO           9857 non-null   int64
#  8   RUIDO                      9857 non-null   int64
#  9   INSEGURIDAD                9857 non-null   int64
#  10  BASURA_INADECUADA          9857 non-null   int64
#  11  INVASION                   9857 non-null   int64
#  12  MOV_ADULTOS_MAYORES        9857 non-null   int64
# ...

# %% [markdown]
# Puedo observar que en algunas columnas hay datos nulos, por ejemplo en la columna que indica si se hipoteco para pedir prestamo bancario hay encuestas sin respuesta para dicha pregunta

# %% [markdown]
# Si voy a la documentacion veo en inseguridad se asigno el valor 1 para la respuesta SI y un 2 para el NO, y eso para muchos de los campos, entonces voy a hacer un remplazo del 2 por un 0, que tiene mas sentido.
# OJO deberia chequear que no le modifico el nombre a algun estrato

# %%
datos = datos_dane[['NOMBRE_ESTRATO','CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].replace(2, 0)
datos
# Out:
#                                      NOMBRE_ESTRATO  CONJUNTO_CERRADO  \
# 0     USAQUÉN: Paseo de Los Libertadores + La Uribe                 1
# 1                                           Usaquén                 1
# 2                CHAPINERO: Pardo Rubio + Chapinero                 0
# 3                                        Los Cedros                 1
# 4                         Ciudad Salitre Occidental                 1
# ...                                             ...               ...
# 9852         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9853         SANTA FE: Las Nieves + Sagrado Corazón                 0
# 9854         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9855         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9856                                   Santa Isabel                 0
#
#       INSEGURIDAD  TERMINALES_BUS  BARES_DISCO  RUIDO  OSCURO_PELIGROSO  \
# ...

# %% [markdown]
# Ahora voy agrupar por UPZ (NOMBRE_ESTRATO) y calcular el promedio

# %%
datos_tratados = datos.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean()
datos_tratados
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   0.11
# Américas                                                      0.62
# Apogeo                                                        0.35
# Arborizadora                                                  0.57
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              0.63
# ...                                                            ...
# Usaquén                                                       0.90
# Venecia                                                       0.47
# Verbenal                                                      0.77
# Zona Franca                                                   0.94
# Álamos                                                        0.65
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# ...

# %% [markdown]
# Veo, por ejemplo, que en 20 de Julio el 11% esta en conjuntos cerrados y el 81% lo considera inseguro.
# Y ahora voy a juntar estos datos tratados con mis datos de inmuebles del comienzo, y lo que los relaciona sera la UPZ que es lo mismo que el NOMBRE_ESTRATO.
# No quiero perder ninguninmueble, por eso lo pongo primero en el merge y hago leftjoin

# %%
pd.merge(inmuebles, datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %% [markdown]
# Los guardo en una variable datos_ln porque los voy a usar en machine learning como tal.
# La columna ya queda renombrada como UPZ

# %%
datos_ml = pd.merge(inmuebles, datos_tratados, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='left')
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9520 entries, 0 to 9519
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9520 non-null   object
#  1   Descripcion               9520 non-null   object
#  2   Habitaciones              9520 non-null   int64
#  3   Banos                     9520 non-null   int64
#  4   Area                      9520 non-null   int64
#  5   Barrio                    9520 non-null   object
#  6   UPZ                       9478 non-null   object
#  7   Valor                     9520 non-null   object
#  8   Moneda                    9520 non-null   object
#  9   Precio                    9520 non-null   object
#  10  Precio_Millones           9520 non-null   float64
#  11  Valor_m²_Millon           9520 non-null   float64
#  12  Valor_m²_Barrio           9520 non-null   float64
# ...

# %% [markdown]
# Las UPZ quedaron como object, quiero que sea numérico porque después voy a hacer una regresion lineal, entonces me traigo el archivo, veo qué tiene ese archivo

# %%
upz = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/archivos-dane/cod_upz.csv')
upz.head()
# Out:
#                            NOMBRE_ESTRATO  COD_UPZ_GRUPO
# 0  SANTA FE: Las Nieves + Sagrado Corazón         814.00
# 1                            Santa Isabel          37.00
# 2   USAQUÉN: Country Club + Santa Bárbara         803.00
# 3      CHAPINERO: Pardo Rubio + Chapinero         816.00
# 4               Ciudad Salitre Occidental         110.00

# %% [markdown]
# la mergeo con datos_ln con un inner, porque quiero que sobrevivan las filas que tiene datos en ambas, al final se agrega una columna con titulo COD_UPZ_GRUPO. Y puedo observar que tiene menos filas y se agrego una columna.

# %%
pd.merge(datos_ml, upz, left_on='UPZ', right_on='NOMBRE_ESTRATO', how='inner')
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 2            Casa         Casa en venta en Zona Noroccidental             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4            Casa         Casa en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
# ...

# %% [markdown]
# puedo observar que ya no tengo datos nulos

# %%
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9318 entries, 0 to 9317
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9318 non-null   object
#  1   Descripcion               9318 non-null   object
#  2   Habitaciones              9318 non-null   int64
#  3   Banos                     9318 non-null   int64
#  4   Area                      9318 non-null   int64
#  5   Barrio                    9318 non-null   object
#  6   UPZ                       9318 non-null   object
#  7   Valor                     9318 non-null   object
#  8   Moneda                    9318 non-null   object
#  9   Precio                    9318 non-null   object
#  10  Precio_Millones           9318 non-null   float64
#  11  Valor_m²_Millon           9318 non-null   float64
#  12  Valor_m²_Barrio           9318 non-null   float64
# ...

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(data=datos_ml, y='Precio_Millones')
plt.show()

# %% [markdown]
# Voy a mirar cuales son los outlawers

# %%
datos_ml.query('Precio_Millones>5000 | Precio_Millones<60')
# Out:
#                      Tipo                                  Descripcion  \
# 207           Apartamento            Apartamento en venta en Chapinero
# 323                 Local                  Local en venta en Chapinero
# 702                  Casa                   Casa en venta en Chapinero
# 708                  Casa                   Casa en venta en Chapinero
# 829           Apartamento   Apartamento en venta en Zona Noroccidental
# 1371          Apartamento             Apartamento en venta en El Chicó
# 1414          Apartamento             Apartamento en venta en El Chicó
# 1429                Local             Local en venta en Quinta Camacho
# 1442                Local             Local en venta en Quinta Camacho
# 1518          Apartamento      Apartamento en venta en Chico Reservado
# 1532          Apartamento          Apartamento en venta en Chico Norte
# 1533          Apartamento          Apartamento en venta en Los Rosales
# ...

# %% [markdown]
# los filtro escribiendo al reves la query

# %%
datos_ml = datos_ml.query('Precio_Millones<5000 & Precio_Millones>60')
datos_ml
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 2            Casa         Casa en venta en Zona Noroccidental             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4            Casa         Casa en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
# ...

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(data=datos_ml, y='Precio_Millones')
plt.show()

# %% [markdown]
# agrego una columna SALARIO_ANUAL (en millones, a la que ya le recorto los ceros)

# %%
datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
datos_ml['SALARIO_ANUAL_MI']
# Out:
# 0      48.42
# 1      48.42
# 2      48.42
# 3      48.42
# 4      48.42
#         ...
# 9313   29.34
# 9314   29.34
# 9315   29.34
# 9316   29.34
# 9317   29.34
# Name: SALARIO_ANUAL_MI, Length: 9277, dtype: float64

# %% [markdown]
# y puedo ver que tengo menos registros que antes de hacer la query en que removi los outlawers

# %% [markdown]
# Ahora veo si hay una regresion entre el valor del m² y el salario anual de las personas

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(data=datos_ml, x='SALARIO_ANUAL_MI', y='Valor_m2_Millon')
plt.ylim((0,15))
plt.show()

# %% [markdown]
# Pero para ver mejor si hay una regresion lineal es usar un scatterplot.
# La regresion lineal me permite predecir un valor numérico.

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=datos_ml, x='SALARIO_ANUAL_MI', y='Valor_m2_Millon')
plt.ylim((0,15))
plt.savefig('/content/drive/MyDrive/Colab Notebooks/archivos-dane/Scatterplot para ver regresion lineal.png', format='png')
plt.show()

# %% [markdown]
# como hay mucha dispersion podria concluirse que no hay mucha relacion entre el salario anual de las personas y el valor del m² en las diferentes UPZ.
# Ahora busco la correlacion entre los datos, me permite ver como se relacionan las variables entre si, cuanto mas cercano a 1 mas se correlacionan directamente, cuanto mas cercano a -1 su correlacion es inversa, y 0 implica no existe ningun tipo de correlacion entre ellas.

# %%
datos_ml.corr()
# Out:
#                           Habitaciones  Banos  Area  Precio_Millones  \
# Habitaciones                      1.00   0.48  0.03             0.22
# Banos                             0.48   1.00  0.06             0.65
# Area                              0.03   0.06  1.00             0.05
# Precio_Millones                   0.22   0.65  0.05             1.00
# Valor_m²_Millon                  -0.23   0.08 -0.04             0.41
# Valor_m²_Barrio                  -0.18   0.16 -0.03             0.32
# Valor_m2_Millon                  -0.23   0.08 -0.04             0.41
# CONJUNTO_CERRADO                 -0.11   0.16 -0.01             0.21
# INSEGURIDAD                       0.12  -0.19 -0.01            -0.26
# TERMINALES_BUS                    0.06  -0.16 -0.01            -0.18
# BARES_DISCO                       0.11  -0.08 -0.01            -0.09
# RUIDO                             0.13  -0.18 -0.00            -0.25
# OSCURO_PELIGROSO                  0.10  -0.20  0.01            -0.23
# ...

# %% [markdown]
# Ahora hago un "mapa de calor" (er este articulo para entender las correlaciones espurias https://www.tylervigen.com/spurious-correlations )que me permite ver a simple vista las mas correlacionadas.
# las espurias son aquellas que por casualidad quedaron relacionadas, aunque en realidad una no influya en la otra.

# %%
plt.figure(figsize=(18, 8))

#mascara = np.triu(np.ones_like(datos_ml.corr(), dtype=bool)) mask=mascara,
heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlación de las variables', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# **scikit-learn** es una biblioteca que me permite hacer machine learning en python (ver la pagina de scikit-learn.org)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# necesito separar los datos para entrenamiento de los datos para prueba de mi modelo (no tiene sentido usar los de entrenamiento en una prueba) con los que realizaré metricas para ver si mi modelo funciona bien, importo otra libreria que me permite separarlos

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ambos paquetes son basico para machine learning. Una buena practica es tomar una **baseline**, que sera una matriz y un vector . Por ejemplo para ver como influye la UPZ en el precio, en test_size el valor por defecto es el 25% de los datos(los que voy a usar para testeo, el 75% seran los que uso para que aprenda, podria modificarlo)

# %%
X =datos_ml[['COD_UPZ_GRUPO']]
y= datos_ml['Precio_Millones']

X_train, X_test, y_train, y_test =train_test_split(X, y,test_size= 0.25,random_state=99)

# %% [markdown]
# veo que valores de x tomaré para entrenar

# %%
X_train
# Out:
#       COD_UPZ_GRUPO
# 7578         810.00
# 8345          98.00
# 1246         816.00
# 8491         809.00
# 4602          47.00
# ...             ...
# 5223          19.00
# 7929          85.00
# 1784         817.00
# 3268          14.00
# 7242          20.00
#
# [6957 rows x 1 columns]

# %% [markdown]
# y cuales para probar

# %%
X_test
# Out:
#       COD_UPZ_GRUPO
# 8428         809.00
# 3079          14.00
# 6927          75.00
# 6861          75.00
# 2357          14.00
# ...             ...
# 7777          85.00
# 1423         817.00
# 3916         803.00
# 8305          98.00
# 3989         803.00
#
# [2320 rows x 1 columns]

# %% [markdown]
# en y_train tendré un panda series con las mismas filas que X_train, y que se corresponden con ella

# %%
y_train
# Out:
# 7578   550.00
# 8345   700.00
# 1246   710.00
# 8491   400.00
# 4602   650.00
#         ...
# 5223   360.00
# 7929   119.00
# 1784   650.00
# 3268   350.00
# 7242   480.00
# Name: Precio_Millones, Length: 6957, dtype: float64

# %% [markdown]
# idem para y_test

# %%
y_test
# Out:
# 8428    650.00
# 3079    550.00
# 6927    327.00
# 6861    260.00
# 2357    460.00
#          ...
# 7777    131.00
# 1423    695.00
# 3916   1000.00
# 8305   1100.00
# 3989    265.00
# Name: Precio_Millones, Length: 2320, dtype: float64

# %% [markdown]
# instancio una regresion lineal genérica y ajusto los datos, en este punto mi modelo esta entrenado

# %%
modelo =LinearRegression()

# %%
modelo.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# uso mi modelo para predecir el valor de y para cada valor de x, y luego compararlo con el valor eesperado de y

# %%
y_predict = modelo.predict(X_test)

# %% [markdown]
# Entre otras existen estas métricas: el error absoluto medio y r² que me da el coeficiente de correlacion (valor entre 0 y 1).
# Las importo

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
baseline_mae = mean_absolute_error(y_test, y_predict)
baseline_mae
# Out:
# 349.01934464671155

# %%
baseline_r2 = r2_score(y_test, y_predict)
baseline_r2
# Out:
# 0.025479229587150987

# %% [markdown]
# es decir el modelo no esta funcionando, ahora tomo mas atributos, es decir ahora si tomo una matriz como X.
# Voy a testearlo también usando los valores de entrenamiento, y veré una leve mejora en los valores de mae y r²

# %%
X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Banos']] #,'CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA'

Y = datos_ml["Precio_Millones"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 241.7714514560005 0.39346598615451067
# 243.29145256483525 0.47023870196651907

# %% [markdown]
# agrego mas columnas

# %%
X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Banos','CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA']] 

Y = datos_ml["Precio_Millones"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 241.92824945672513 0.4253766410151324
# 243.25185242026816 0.48545749312201236

# %% [markdown]
# **Si hubiera filtrado mas outlawers, tendria mejores resultados**, podria repetirlo para precios entre 600 y 1000 millones

# %% [markdown]
# Ahora voy a **predecir** cuanto cuesta un inmueble con las siguientes caracteristicas:
# el codigo de UPZ es 816,
# tiene 3 habitaciones,
# tiene 2 baños,
# esta en un conjunto cerrado,
# la persona gana 50 millones anuales y
# tiene escritura
# Debo pasar los datos en formato de dataframe.

# %%
modelo_1.predict([[816,3,2,1,50,1]])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([476.01220375])
